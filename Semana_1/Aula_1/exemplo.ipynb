# %%
nome = 'Mourao'
profissao = "Desenvolvedor "

print(nome)

nome = '' # string
print(nome)
# Out:
# Alisson
# Andrei

# %%
idade = 27 # int

# %%
saldo = 100.00 # float

# %%
lista = ["Andrei", "João", "sabrina", 25, [1,2,3], 4.5]
print(lista)
# Out:
# ['Andrei', 'João', 'sabrina', 25, [1, 2, 3], 4.5]

# %%
alunos_aprovados = ()

# %%
print(alunos_aprovados)
# Out:
# ('Ana', 'João', 'Jaqueline', 'Henrique')

# %%
print(alunos_aprovados[0])
# Out:
# Ana

# %%
lista.append(2)

# %%
print(alunos_aprovados)
# Out:
# ()

# %%
pontos = {10, 45, 11, 11, 2, 8}
print(pontos)
# Out:
# {2, 8, 10, 11, 45}

# %%
print(pontos.pop())
# Out:
# 2

# %%
print(pontos.pop())
# Out:
# 8

# %%
type(pontos)
# Out:
# set

# %%
aluno = {
    'nome': "João",
    'idade': 28,
    'cidade': "Americana"
}

print(aluno['nome'])
# Out:
# João

# %%
aluno['nome'] = "Andrei"

# %%
print(aluno)
# Out:
# {'nome': 'Andrei', 'idade': 28, 'cidade': 'Americana'}

# %%
complex_value = 2 + 5j

# %%
print(complex_value)
# Out:
# (2+5j)

# %%
type(complex_value)
# Out:
# complex

# %%
bool(True)
# Out:
# True

# %%
idade_minima_cnh = aluno['idade'] <= 18
idade_minima_cnh
# Out:
# False
