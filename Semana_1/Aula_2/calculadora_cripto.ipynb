# %%
## Calculadora cripto 
try: 
    saldo = float(input("digite seu saldo?"))
    tipo = input("calculo mensal ou anual?")
    
    if(tipo == "anual"):
        taxa = float(input("qual a taxa de juros anual?")) / 100
        anos = int(input("quantos anos?")
                   
    if(tipo == "mensal"):
        taxa = float(input("qual a taxa de juros mensal?")) / 100
        meses = int(input("quantos meses?")
                    
    if(saldo < 0 or meses < 0):
        print("Valores negativos não liberados")
    elif(tipo == "mensal"):
        motante_final = saldo * (taxa + 1) ** meses
    else:
        motante_final = saldo * (taxa + 1) ** anos


     print(motante_final)
    
except:
    print("erro inesperado")
