# %%
import pandas as pd

# %%
devedores = pd.read_csv("dataset/Devedores.csv", sep=';', encoding='latin-1')
devedores
# Out:
#      DATA DE GERAÇÃO    CPF/CNPJ DEVEDOR   TIPO DE PESSOA TIPO DO DEVEDOR  \
# 0         04/12/2023  68.559.467/0001-00  Pessoa jurídica       Principal
# 1         04/12/2023      XXX.160.007-XX    Pessoa física  Corresponsável
# 2         04/12/2023  81.545.550/0001-98  Pessoa jurídica       Principal
# 3         04/12/2023  59.960.658/0001-98  Pessoa jurídica       Principal
# 4         04/12/2023  03.887.547/0001-49  Pessoa jurídica       Principal
# ...              ...                 ...              ...             ...
# 2571      04/12/2023      XXX.858.898-XX    Pessoa física       Principal
# 2572      04/12/2023  18.941.229/0001-96  Pessoa jurídica       Principal
# 2573      04/12/2023  33.884.941/0001-94  Pessoa jurídica       Principal
# 2574      04/12/2023  07.737.549/0001-02  Pessoa jurídica       Principal
# 2575      04/12/2023  02.440.198/0001-50  Pessoa jurídica       Principal
#
#                                         NOME DO DEVEDOR  \
# ...

# %%
aposentadoria = pd.read_csv('dataset/Aposentados.csv', sep=';', encoding='latin-1')
aposentadoria
# Out:
#                                   Nome             CPF SituaÃ§Ã£o VÃ­nculo  \
# 0                  ABADIA MARCIA CUNHA  ***.161.491-**          Aposentado
# 1         ABDIAS CASSIO MARROCOS GOMES  ***.297.631-**          Aposentado
# 2           ABDIEL ANDRIOLO DE ANDRADE  ***.895.388-**          Aposentado
# 3               ABDON LOPES DE MENESES  ***.983.931-**          Aposentado
# 4                   ABEL ALFREDO FILHO  ***.347.385-**          Aposentado
# ...                                ...             ...                 ...
# 5400             ZULEICA DE MELO TELES  ***.533.991-**          Aposentado
# 5401         ZULEICA MARIA SOUZA PORTO  ***.454.201-**          Aposentado
# 5402              ZULMA GONCALVES DIAS  ***.828.526-**          Aposentado
# 5403                     ZULMAR MAYETA  ***.113.787-**          Aposentado
# 5404  ZULMIRA MARIA BERNARDES NORMANDO  ***.805.121-**          Aposentado
#
# ...

# %%
devedores_cpf = devedores[devedores['TIPO DE PESSOA'] == "Pessoa física"]

# %%
devedores_cpf ['CPF/CNPJ DEVEDOR']
# Out:
# 1       XXX.160.007-XX
# 6       XXX.340.947-XX
# 9       XXX.028.317-XX
# 10      XXX.993.977-XX
# 11      XXX.402.247-XX
#              ...
# 2563    XXX.619.996-XX
# 2564    XXX.453.768-XX
# 2566    XXX.875.635-XX
# 2568    XXX.728.571-XX
# 2571    XXX.858.898-XX
# Name: CPF/CNPJ DEVEDOR, Length: 899, dtype: object

# %%
aposentadoria['CPF'] = aposentadoria['CPF'].str[3:12]
aposentadoria
# Out:
#                                   Nome     CPF SituaÃ§Ã£o VÃ­nculo MatrÃ­cula  \
# 0                  ABADIA MARCIA CUNHA  1.491-          Aposentado   000*****
# 1         ABDIAS CASSIO MARROCOS GOMES  7.631-          Aposentado   000*****
# 2           ABDIEL ANDRIOLO DE ANDRADE  5.388-          Aposentado   000*****
# 3               ABDON LOPES DE MENESES  3.931-          Aposentado   000*****
# 4                   ABEL ALFREDO FILHO  7.385-          Aposentado   000*****
# ...                                ...     ...                 ...        ...
# 5400             ZULEICA DE MELO TELES  3.991-          Aposentado   999*****
# 5401         ZULEICA MARIA SOUZA PORTO  4.201-          Aposentado   999*****
# 5402              ZULMA GONCALVES DIAS  8.526-          Aposentado   999*****
# 5403                     ZULMAR MAYETA  3.787-          Aposentado   999*****
# 5404  ZULMIRA MARIA BERNARDES NORMANDO  5.121-          Aposentado   999*****
#
# ...

# %%
devedores_cpf.loc['CPF/CNPJ DEVEDOR'] = devedores_cpf['CPF/CNPJ DEVEDOR'].str[3:12]
devedores_cpf
# Out:
#                  DATA DE GERAÇÃO CPF/CNPJ DEVEDOR TIPO DE PESSOA  \
# 1                     04/12/2023   XXX.160.007-XX  Pessoa física
# 6                     04/12/2023   XXX.340.947-XX  Pessoa física
# 9                     04/12/2023   XXX.028.317-XX  Pessoa física
# 10                    04/12/2023   XXX.993.977-XX  Pessoa física
# 11                    04/12/2023   XXX.402.247-XX  Pessoa física
# ...                          ...              ...            ...
# 2564                  04/12/2023   XXX.453.768-XX  Pessoa física
# 2566                  04/12/2023   XXX.875.635-XX  Pessoa física
# 2568                  04/12/2023   XXX.728.571-XX  Pessoa física
# 2571                  04/12/2023   XXX.858.898-XX  Pessoa física
# CPF/CNPJ DEVEDOR             NaN              NaN            NaN
#
#                  TIPO DO DEVEDOR                 NOME DO DEVEDOR  \
# 1                 Corresponsável      Jose Carlos da Silva Gomes
# ...

# %%
aposentadoria['Nome'] = aposentadoria['Nome'].str.upper()
aposentadoria['Nome']
# Out:
# 0                    ABADIA MARCIA CUNHA
# 1           ABDIAS CASSIO MARROCOS GOMES
# 2             ABDIEL ANDRIOLO DE ANDRADE
# 3                 ABDON LOPES DE MENESES
# 4                     ABEL ALFREDO FILHO
#                       ...
# 5400               ZULEICA DE MELO TELES
# 5401           ZULEICA MARIA SOUZA PORTO
# 5402                ZULMA GONCALVES DIAS
# 5403                       ZULMAR MAYETA
# 5404    ZULMIRA MARIA BERNARDES NORMANDO
# Name: Nome, Length: 5405, dtype: object
