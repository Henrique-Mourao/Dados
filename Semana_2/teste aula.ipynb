# %%
from pydoc import describe

import pandas as pd

# %%
devedores = pd.read_csv('dataset/Devedores.csv', sep=";", encoding="latin-1")

# %%
devedores.columns
# Out:
# Index(['DATA DE GERAÇÃO', 'CPF/CNPJ DEVEDOR', 'TIPO DE PESSOA',
#        'TIPO DO DEVEDOR', 'NOME DO DEVEDOR', 'NÚMERO DO TERMO DE INSCRIÇÃO',
#        'DATA DA INSCRIÇÃO', 'SEQUENCIAL DO CRÉDITO', 'SITUAÇÃO DO CRÉDITO',
#        'MOTIVO DA SUSPENSÃO', 'ORIGEM', 'CREDOR',
#        'SALDO DEVEDOR SEM HONORÁRIOS', 'OBSERVAÇÃO'],
#       dtype='object')

# %%
devedores.describe()
# Out:
#        DATA DE GERA??O CPF/CNPJ DEVEDOR   TIPO DE PESSOA TIPO DO DEVEDOR  \
# count             2576             2568             2568            2576
# unique               1             2238                2               2
# top         04/12/2023   XXX.827.945-XX  Pessoa jur?dica       Principal
# freq              2576               17             1669            2315
#
#                                   NOME DO DEVEDOR  \
# count                                        2576
# unique                                       2241
# top     Stephane Joseph Ghislain Mery de Montigny
# freq                                           17
#
#        N?MERO DO TERMO DE INSCRI??O DATA DA INSCRI??O SEQUENCIAL DO CR?DITO  \
# count                          2576              2576                  2576
# unique                         2306              1398                  2315
# top                       0002/1984        10/06/2003        CR2013/0005435
# freq                              6                23                     6
#
#        SITUA??O DO CR?DITO                                MOTIVO DA SUSPENS?O  \
# count                 2576                                                225
# unique                   4                                                  4
# top            Em execu??o  ? suspensa a cobran?a por for?a de dep?sito in...
# freq                  2090                                                 74
#
#        ORIGEM         CREDOR SALDO DEVEDOR SEM HONOR?RIOS  \
# count    2576           2576                         2576
# unique      4              4                         2072
# top     Multa  Banco Central                 R$ 38.692,27
# freq     2358           2555                           16
#
#                                                OBSERVA??O
# count                                                  13
# unique                                                  1
# top      O saldo devedor sem honor?rios n?o correspond...
# freq                                                   13

# %%
devedores['OBSERVAÇÃO'].unique()
# Out:
# array([nan,
#        ' O saldo devedor sem honorários não corresponde ao valor exato da dívida. Consultar a Procuradoria-Geral do Banco Central. '],
#       dtype=object)

# %%
devedores['ORIGEM'].unique()
# Out:
# array(['Multa', 'Contrato', 'Diversos com origem administrativa',
#        'Relativos a servidor'], dtype=object)

# %%
devedores.columns
# Out:
# Index(['DATA DE GERA??O', 'CPF/CNPJ DEVEDOR', 'TIPO DE PESSOA',
#        'TIPO DO DEVEDOR', 'NOME DO DEVEDOR', 'N?MERO DO TERMO DE INSCRI??O',
#        'DATA DA INSCRI??O', 'SEQUENCIAL DO CR?DITO', 'SITUA??O DO CR?DITO',
#        'MOTIVO DA SUSPENS?O', 'ORIGEM', 'CREDOR',
#        'SALDO DEVEDOR SEM HONOR?RIOS', 'OBSERVA??O'],
#       dtype='object')

# %%
devedores[('MOTIVO DA SUSPENSÃO')].unique()
# Out:
# array([nan, 'Aguardando encerramento da falência', 'Outros motivos',
#        'É suspensa a cobrança por força de depósito integral judicial',
#        'Decisão judicial'], dtype=object)

# %%
devedores.describe()
# Out:
#        DATA DE GERAÇÃO CPF/CNPJ DEVEDOR   TIPO DE PESSOA TIPO DO DEVEDOR  \
# count             2576             2568             2568            2576
# unique               1             2238                2               2
# top         04/12/2023   XXX.827.945-XX  Pessoa jurídica       Principal
# freq              2576               17             1669            2315
#
#                                   NOME DO DEVEDOR  \
# count                                        2576
# unique                                       2241
# top     Stephane Joseph Ghislain Mery de Montigny
# freq                                           17
#
#        NÚMERO DO TERMO DE INSCRIÇÃO DATA DA INSCRIÇÃO SEQUENCIAL DO CRÉDITO  \
# count                          2576              2576                  2576
# unique                         2306              1398                  2315
# top                       0002/1984        10/06/2003        CR2013/0005435
# freq                              6                23                     6
#
#        SITUAÇÃO DO CRÉDITO                                MOTIVO DA SUSPENSÃO  \
# count                 2576                                                225
# unique                   4                                                  4
# top            Em execução  É suspensa a cobrança por força de depósito in...
# freq                  2090                                                 74
#
#        ORIGEM         CREDOR SALDO DEVEDOR SEM HONORÁRIOS  \
# count    2576           2576                         2576
# unique      4              4                         2072
# top     Multa  Banco Central                 R$ 38.692,27
# freq     2358           2555                           16
#
#                                                OBSERVAÇÃO
# count                                                  13
# unique                                                  1
# top      O saldo devedor sem honorários não correspond...
# freq                                                   13

# %%
aposentados = pd.read_csv('dataset/Aposentados.csv', sep=";", encoding="latin-1", skiprows=2)
aposentados
# Out:
#           ABDIAS CASSIO MARROCOS GOMES  ***.297.631-**  Aposentado  000*****  \
# 0           ABDIEL ANDRIOLO DE ANDRADE  ***.895.388-**  Aposentado  000*****
# 1               ABDON LOPES DE MENESES  ***.983.931-**  Aposentado  000*****
# 2                   ABEL ALFREDO FILHO  ***.347.385-**  Aposentado  000*****
# 3         ABEL AMBROSIO DA SILVA FILHO  ***.210.784-**  Aposentado  000*****
# 4              ABEL EUSTAQUIO DE FARIA  ***.849.701-**  Aposentado  000*****
# ...                                ...             ...         ...       ...
# 5398             ZULEICA DE MELO TELES  ***.533.991-**  Aposentado  999*****
# 5399         ZULEICA MARIA SOUZA PORTO  ***.454.201-**  Aposentado  999*****
# 5400              ZULMA GONCALVES DIAS  ***.828.526-**  Aposentado  999*****
# 5401                     ZULMAR MAYETA  ***.113.787-**  Aposentado  999*****
# 5402  ZULMIRA MARIA BERNARDES NORMANDO  ***.805.121-**  Aposentado  999*****
#
#       25201  BANCO CENTRAL DO BRASIL BANCO CENTRAL DO BRASIL.1  BCESPTE   IV  \
# 0     25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE   II
# 1     25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPTE   IV
# 2     25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE   IV
# 3     25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE  III
# 4     25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE   IV
# ...     ...                      ...                       ...      ...  ...
# 5398  25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAB  III
# 5399  25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAC  III
# 5400  25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAC    I
# 5401  25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE   IV
# 5402  25201  BANCO CENTRAL DO BRASIL   BANCO CENTRAL DO BRASIL  BCESPAE  III
#
#       Unnamed: 9  Unnamed: 10  RJU   1107143  24/12/2021  04/01/2022  112570  \
# 0            NaN          NaN  RJU   1155040  27/02/1997  27/02/1997
# 1            NaN          NaN  RJU   1107143  14/10/2008  15/10/2008   47447
# 2            NaN          NaN  RJU   1107143  28/11/2022  01/12/2022  115578
# 3            NaN          NaN  RJU   1155083  30/12/1997  30/12/1997
# 4            NaN          NaN  RJU   1107143  09/09/2011  12/09/2011   67061
# ...          ...          ...  ...       ...         ...         ...     ...
# 5398         NaN          NaN  RJU   1155083  28/04/1998  28/04/1998
# 5399         NaN          NaN  RJU   1155083  27/03/1998  27/03/1998
# 5400         NaN          NaN  RJU  11020871  10/04/2000  10/04/2000
# 5401         NaN          NaN  RJU   1107143  02/07/2018  03/07/2018   98600
# 5402         NaN          NaN  RJU   1155083  03/04/1997  03/04/1997
#
#       Unnamed: 16 Unnamed: 17 Unnamed: 18  Unnamed: 19
# 0             NaN         NaN                      NaN
# 1             NaN         NaN                      NaN
# 2             NaN         NaN         NaN          NaN
# 3             NaN         NaN                      NaN
# 4             NaN         NaN                      NaN
# ...           ...         ...         ...          ...
# 5398          NaN         NaN                      NaN
# 5399          NaN         NaN                      NaN
# 5400          NaN         NaN                      NaN
# 5401          NaN         NaN                      NaN
# 5402          NaN         NaN                      NaN
#
# [5403 rows x 20 columns]

# %%
aposentados.columns
# Out:
# Index(['ABDIAS CASSIO MARROCOS GOMES', '***.297.631-**', 'Aposentado',
#        '000*****', '25201', 'BANCO CENTRAL DO BRASIL',
#        'BANCO CENTRAL DO BRASIL.1', 'BCESPTE', 'IV', 'Unnamed: 9',
#        'Unnamed: 10', 'RJU', '1107143', '24/12/2021', '04/01/2022', '112570',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
aposentados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5395 entries, 0 to 5394
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ABELARDO DUARTE DE MELO SOBRINHO  5395 non-null   object
#  1   ***.056.467-**                    5395 non-null   object
#  2   Aposentado                        5395 non-null   object
#  3   001*****                          5395 non-null   object
#  4   25201                             5395 non-null   int64
#  5   BANCO CENTRAL DO BRASIL           5395 non-null   object
#  6   BANCO CENTRAL DO BRASIL.1         5395 non-null   object
#  7   BCESPAE                           5395 non-null   object
#  8   IV                                5395 non-null   object
#  9   Unnamed: 9                        0 non-null      float64
#  10  Unnamed: 10                       0 non-null      float64
#  11  RJU                               5395 non-null   object
#  12  1107143                           5395 non-null   object
#  13  06/05/2010                        5395 non-null   object
#  14  07/05/2010                        5395 non-null   object
#  15  57520                             5395 non-null   object
#  16  Unnamed: 16                       0 non-null      float64
#  17  Unnamed: 17                       43 non-null     object
#  18                                    5054 non-null   object
#  19  Unnamed: 19                       43 non-null     float64
# dtypes: float64(4), int64(1), object(15)
# memory usage: 843.1+ KB

# %%
aposentados.describe().T
# Out:
#                                                    count unique  \
# Banco Central do Brasil  -  Aposentados no Regi...  5406   5399
# Unnamed: 1                                          5406   5369
# Unnamed: 2                                          5406      2
# Unnamed: 3                                          5406    939
# Unnamed: 4                                          5406      2
# Unnamed: 5                                          5406      2
# Unnamed: 6                                          5406      2
# Unnamed: 7                                          5406     11
# Unnamed: 8                                          5406      5
# Unnamed: 9                                             1      1
# Unnamed: 10                                            1      1
# Unnamed: 11                                         5406      2
# Unnamed: 12                                         5406     33
# Unnamed: 13                                         5406   2089
# Unnamed: 14                                         5406   2117
# Unnamed: 15                                         5406   3088
# Unnamed: 16                                            1      1
# Unnamed: 17                                           44      2
# Unnamed: 18                                         5063     18
# Unnamed: 19                                           44     13
#
#                                                                                   top  \
# Banco Central do Brasil  -  Aposentados no Regi...          CARLOS ALBERTO DOS SANTOS
# Unnamed: 1                                                             ***.204.501-**
# Unnamed: 2                                                                 Aposentado
# Unnamed: 3                                                                   684*****
# Unnamed: 4                                                                      25201
# Unnamed: 5                                                    BANCO CENTRAL DO BRASIL
# Unnamed: 6                                                    BANCO CENTRAL DO BRASIL
# Unnamed: 7                                                                    BCESPAE
# Unnamed: 8                                                                         IV
# Unnamed: 9                                                                 Referência
# Unnamed: 10                                                                     Nível
# Unnamed: 11                                                                       RJU
# Unnamed: 12                                                                   1107143
# Unnamed: 13                                                                14/06/1997
# Unnamed: 14                                                                14/06/1997
# Unnamed: 15
# Unnamed: 16                                         Ingresso no Serviço Público Civil
# Unnamed: 17                                                                  Portaria
# Unnamed: 18
# Unnamed: 19                                                                     37740
#
#                                                     freq
# Banco Central do Brasil  -  Aposentados no Regi...     2
# Unnamed: 1                                             2
# Unnamed: 2                                          5405
# Unnamed: 3                                            98
# Unnamed: 4                                          5405
# Unnamed: 5                                          5405
# Unnamed: 6                                          5405
# Unnamed: 7                                          3637
# Unnamed: 8                                          3184
# Unnamed: 9                                             1
# Unnamed: 10                                            1
# Unnamed: 11                                         5405
# Unnamed: 12                                         2267
# Unnamed: 13                                          661
# Unnamed: 14                                          661
# Unnamed: 15                                         2294
# Unnamed: 16                                            1
# Unnamed: 17                                           43
# Unnamed: 18                                         5019
# Unnamed: 19                                           16

# %%
aposentados.count().T
# Out:
# Banco Central do Brasil  -  Aposentados no Regime Jurídico Único - Posição de 30/09/2023    5406
# Unnamed: 1                                                                                  5406
# Unnamed: 2                                                                                  5406
# Unnamed: 3                                                                                  5406
# Unnamed: 4                                                                                  5406
# Unnamed: 5                                                                                  5406
# Unnamed: 6                                                                                  5406
# Unnamed: 7                                                                                  5406
# Unnamed: 8                                                                                  5406
# Unnamed: 9                                                                                     1
# Unnamed: 10                                                                                    1
# Unnamed: 11                                                                                 5406
# Unnamed: 12                                                                                 5406
# Unnamed: 13                                                                                 5406
# Unnamed: 14                                                                                 5406
# Unnamed: 15                                                                                 5406
# Unnamed: 16                                                                                    1
# Unnamed: 17                                                                                   44
# Unnamed: 18                                                                                 5063
# Unnamed: 19                                                                                   44
# dtype: int64

# %%
aposentados.columns
# Out:
# Index(['ABDIAS CASSIO MARROCOS GOMES', '***.297.631-**', 'Aposentado',
#        '000*****', '25201', 'BANCO CENTRAL DO BRASIL',
#        'BANCO CENTRAL DO BRASIL.1', 'BCESPTE', 'IV', 'Unnamed: 9',
#        'Unnamed: 10', 'RJU', '1107143', '24/12/2021', '04/01/2022', '112570',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')
