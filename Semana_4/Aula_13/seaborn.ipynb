# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Configurando o tema visual
sns.set_theme(style="whitegrid")

# Get dataset pronto
tips = sns.load_dataset('tips')

print("=== As Primeiras Mesas Atendidas ===")
tips.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
print("\n=== Estatísticas Básicas ===")
print(tips.describe())

print("unicos")
print(tips['time'].unique())
print(tips['day'].unique())

# %%
# Criando a figura (sim, ainda usamos plt.subplots para controlar o tamanho!)
fig, ax = plt.subplots(figsize=(10, 6))

# O comando mágico do Seaborn
sns.histplot(data=tips, x='total_bill', kde=True, color='teal', ax=ax)

ax.set_title('Distribuição do Valor das Contas (Histograma)', fontsize=14)
ax.set_xlabel('Valor da Conta ($)')
ax.set_ylabel('Frequência (Qtd Mesas)')

plt.show()

# %%
tips['tip'].corr(tips['total_bill'])

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Scatterplot: X e Y são numéricos
sns.scatterplot(data=tips, x='total_bill', y='tip',  
                s=100,
                color="red",
                ax=ax, 
                 )
ax.set_title('Relação: Valor da Conta vs. Gorjeta')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Scatterplot: X e Y são numéricos
sns.scatterplot(data=tips, x='total_bill', y='tip', s=200, alpha=0.7, ax=ax)
sns.regplot(data=tips, x='total_bill', y='tip', scatter=True, color='red', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))


sns.set(rc={'axes.facecolor':'white', 'figure.facecolor':'white'})
sns.set_style(style='darkgrid')
sns.scatterplot(data=tips, 
                x='total_bill', 
                y='tip', 
                hue='time',     # Colore por horário
                style='sex',    # Muda forma por gênero
                s=100,          # Tamanho da bolinha
                palette=['red', 'blue'], # Paleta de cores moderna
                ax=ax)

ax.set_title('Análise Multivariada: Conta vs Gorjeta (Por Horário e Gênero)')
plt.legend(bbox_to_anchor=(1, 1), loc=2) # Joga a legenda para fora
plt.tight_layout()
plt.show()

# %%
# Jointplot une o Scatter (meio) com os Histogramas (bordas)
sns.jointplot(data=tips, 
              x='total_bill', 
              y='tip', kind='kde', 
              height=10, color='#4CB391')
## plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]
plt.show()

# %% [markdown]
# ## Titanic

# %%
titanic = sns.load_dataset('titanic')
titanic.head()

# %%
titanic.describe()

# %%
titanic.info()

# %%
plt.figure(figsize=(10, 8))
sns.histplot(data=titanic, x='age', kde=True)
plt.title('Idade dos Passageiros')
plt.show()

plt.figure(figsize=(20, 10))
sns.scatterplot(data=titanic, x='age', y='fare', hue='alive', style='class', s=60)
plt.title('Sobrevivência por Idade e Preço da Passagem')
plt.show()

#desafio: remover outliers do scatterplot

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(data=titanic, 
                x='age', 
                y='fare', 
                hue='alive', 
                style='class', 
                s=60)
plt.title('Sobrevivência por Idade e Preço da Passagem')

plt.ylim(0,300)
plt.show()

# %%
#metodo andrei/ana/carol
titanic_filtrado = titanic[titanic['fare'] <= 300]
 
plt.figure(figsize=(20,10))
sns.scatterplot(data=titanic_filtrado,x='age', y='fare', hue='alive', style='class', s=60)
plt.title('sobrevivencia por idade e preço da passagem')

# %%
# metodo Pietra
#filtro = titanic[titanic['fare'] <= 300]

plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=titanic, x='age',
    y='fare', hue='alive', 
    style='class', s=60)
plt.title('Sobrevivência por Idade e Preço da Passagem')
plt.ylim(-10, 300)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(24, 10))

titanic_no_outliers = titanic[
    (titanic['age'].between(titanic['age']
    .quantile(0.05), titanic['age'].quantile(0.95))) &
    (titanic['fare']
    .between(titanic['fare']
    .quantile(0.05), titanic['fare'].quantile(0.95)))
]
 
sns.scatterplot(data=titanic, x='age', y='fare', hue='alive', style='class', s=60, ax=axes[0])
axes[0].set_title('COM Outliers', fontsize=14, fontweight='bold')
 
sns.scatterplot(data=titanic_no_outliers, x='age', y='fare', hue='alive', style='class', s=60, ax=axes[1])
axes[1].set_title('SEM Outliers', fontsize=14, fontweight='bold')
 
plt.tight_layout()
plt.show()
 
#remover os outliers do scatterplot
