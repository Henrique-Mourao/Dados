# %%
from transformers import pipeline
import pandas as pd

# %%
model_leve = "./modelo_sentimento_offline"

# %%
analisador_leve = pipeline(
    "sentiment-analysis",
    model=model_leve,
    tokenizer=model_leve
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 analisador_leve = pipeline(
#       2     "sentiment-analysis",
#       3     model=model_leve,
#       4     tokenizer=model_leve
#       5 )
#
# File c:\Users\henrique.mourao\Downloads\Projeto_Final\.venv\Lib\site-packages\transformers\pipelines\__init__.py:827, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     822         raise ValueError(
#     823             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#     824             " arguments might conflict, use only one.)"
#     825         )
#     826 if dtype is not None:
# --> 827     if isinstance(dtype, str) and hasattr(torch, dtype):
#     828         dtype = getattr(torch, dtype)
#     829     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined

# %%
def analisar_completo(text):
    retorno = analisador_leve(text)
    return retorno[0]['label'], retorno[0]['score']

reviews[['score', 'sentimento']] = reviews['texto'].apply(
    lambda x: pd.Series(
        analisar_completo(x)
        )
    )
